# %%
import random
list=[
'Break_continue_pass',
'conditionalStatements',
'data_types',
'Dictionaries',
'Functions',
'list',
'Loops',
'Oprators',
'randommodule',
'round_func',
'sets.ipynb',
'tuples.ipynb',
'TypeCasting, error',
'Types_Arguements',
'variables1'
]
to_do=[]
for i in range(3):
    picked=random.choice(list)
    if picked in to_do:
        picked=random.choice(list)       
    else:
        to_do.append(picked)
print(to_do)
# Out:
# ['data_types', 'Functions']

# %%
import random

topics = [
    'Break_continue_pass',
    'conditionalStatements',
    'data_types',
    'Dictionaries',
    'Functions',
    'list',
    'Loops',
    'Oprators',
    'randommodule',
    'round_func',
    'sets',
    'tuples',
    'TypeCasting_error',
    'Types_Arguements',
    'variables1'
]

print(random.sample(topics, 3))
# Out:
# ['round_func', 'Types_Arguements', 'Functions']
